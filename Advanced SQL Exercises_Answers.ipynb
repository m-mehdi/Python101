# %% [markdown]
# ## Advanced SQL Exercises (with Answers)

# %% [markdown]
# Today we will work with the 'chinook' database through SQLite. The chinook database has 11 different tables we can query and is a good database for us to practice our SQL skills. The following diagram shows us how these tables are related to one another in our database.
#
# <img src ='Chinook_Schema.png'>

# %% [markdown]
# Run the two following cells to get started working with SQLite on Jupyter. Remember that you need to use the magic functions (%sql or %%sql) when trying to run SQL commands; the former is used for single line commands whilst the latter is for multiple lines.

# %%
# !pip install ipython-sql

# %%
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %% [markdown]
# # General Notes about Syntax
#
#
# - When using SQL keywords such as SFW(SELECT, FROM, WHERE) it is best practice to use capital letters even though SQL itself is not case sensitive. This produces more human-readable code, and is easier to interpret and pick up where we left off.
# - Make sure to end each query with ';'. This is not strictly necessary, but will signify the 'end' of our query
# - When setting an alias, you can either explicitly mention 'FirstName' AS first_name or you could just assign the alias after a space 'FirstName' first_name. The method you choose comes down to personal preference
# - When using the LIKE operator, the % symbol is a 'wildcard' that could refer to characters of any length. The _ symbol refers to a 'wildcard' single character
# - In this toy dataset it is completely fine to select all with * however in real-world we should explicitly choose the columns we want so as to avoid costly computations

# %% [markdown]
# # Section 1: Querying Data

# %% [markdown]
# ## Problem 1

# %% [markdown]
# It is tradition in your company to celebrate the birthdays of everyone born in the same month together. As we are approaching the end of April, we need to find out which employees have their birthdays in May. Query the 'employees' table to find this information.

# %%
# %sql SELECT FirstName, LastName FROM employees WHERE BirthDate LIKE '%-05-%';
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Robert', 'King')]

# %% [markdown]
# ## Problem 2

# %% [markdown]
# A new law has been passed in parliament that makes it mandatory for companies that have more than or equal to 5 employees in a given city to declare this number to their local city council. Which cities are required to make this report to the city council? Query the 'employees' table for this information.

# %%
# %%sql SELECT City, COUNT(EmployeeId) AS Number_Of_Employees
# FROM employees
# GROUP BY City
# HAVING Number_Of_Employees >= 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Calgary', 5)]

# %% [markdown]
# ## Problem 3

# %% [markdown]
# You are performing an audit on all the tracks you have in your database. Can you retrieve the following information:
#
# - The total number of tracks in your database
# - The total number of unique albums present in your database
# - The number of unique unit prices, and the number of tracks for each of these prices

# %%
# %sql SELECT COUNT(*) AS 'Total Tracks' FROM tracks;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3503,)]

# %%
# %sql SELECT COUNT (DISTINCT AlbumId) AS 'Number of Albums' FROM tracks;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(347,)]

# %%
# %sql SELECT UnitPrice, COUNT(UnitPrice) AS Amount FROM tracks GROUP BY UnitPrice;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(0.99, 3290), (1.99, 213)]

# %% [markdown]
# ## Problem 4a

# %% [markdown]
# A customer has just walked into the store looking to buy an album for his father. He cannot remember exactly which album his dad wanted, but he does remember that this particular album has at least 10 song names with the word 'The' in it. Can you find the AlbumId for this album?

# %%
# %%sql SELECT AlbumId, COUNT(*) AS Number_of_The
# FROM tracks
# WHERE name LIKE '%The%'
# GROUP BY AlbumId
# HAVING Number_of_The > 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(253, 16)]

# %% [markdown]
# ## Problem 4b

# %% [markdown]
# Now that you found the AlbumId, look up the tables to find the name of the artist, and the name of the album

# %%
# %sql SELECT * FROM albums LIMIT 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'For Those About To Rock We Salute You', 1)]

# %%
# %sql SELECT * FROM artists LIMIT 1;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'AC/DC')]

# %%
# %%sql SELECT Title AS Album, Name AS Artist
# FROM albums al
# INNER JOIN artists a
# ON a.ArtistId = al.ArtistId
# WHERE AlbumId = 253;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Battlestar Galactica (Classic), Season 1', 'Battlestar Galactica (Classic)')]

# %% [markdown]
# ## Problem 4c

# %% [markdown]
# Query the data to find the artist name and albums for all records with albumId between 100 and 110

# %%
# %%sql SELECT AlbumId, Title AS Album, Name AS Artist_Name
# FROM albums al
# INNER JOIN artists a
# ON a.ArtistId = al.ArtistId
# WHERE AlbumId BETWEEN
# 100 AND 110;

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Working with the tracks and invoice_items tables, can you determine which genres are generating the most revenue for your business? This would require the following information
#
# - Quantity of tracks sold by GenreId
# - Revenue generated for each GenreId IF the revenue is greater than 100
#
# Hint: You need to use a JOIN and a GROUP BY
#
# Hint 2: Revenue is given by Price * Quantity

# %%
# %%sql SELECT t.GenreId,
# COUNT(i.Quantity) AS Quantity,
# ROUND(SUM(i.UnitPrice * i.Quantity),2) AS Revenue
#
# FROM invoice_items i
#
# INNER JOIN tracks t
# ON t.TrackId = i.TrackId
#
# GROUP BY GenreId
# HAVING Revenue > 100;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 835, 826.65), (3, 264, 261.36), (4, 244, 241.56), (7, 386, 382.14)]

# %%
# %sql SELECT * FROM genres LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Rock'),
#  (2, 'Jazz'),
#  (3, 'Metal'),
#  (4, 'Alternative & Punk'),
#  (5, 'Rock And Roll')]

# %% [markdown]
# ## Problem 6

# %% [markdown]
# What are the names of the first five songs that will play from the 'Classical' playlist?
#
# Hint: Query the playlist_track and tracks tables for this information

# %%
# %%sql SELECT name FROM playlist_track pt
# INNER JOIN tracks t
# ON pt.TrackId = t.TrackId
# WHERE PlaylistId == (SELECT PlaylistId FROM playlists WHERE Name == 'Classical')
# LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Intoitus: Adorate Deum',),
#  ('Miserere mei, Deus',),
#  ('Canon and Gigue in D Major: I. Canon',),
#  ('Concerto No. 1 in E Major, RV 269 "Spring": I. Allegro',),
#  ('Concerto for 2 Violins in D Minor, BWV 1043: I. Vivace',)]

# %% [markdown]
# ## Problem 7

# %% [markdown]
# Your company is running a promotion to provide a huge discount coupon to three customers that spent the most money in a single transaction in 2013.  Can you determine the CustomerId for these customers and the amount they paid?
#
# Hint: Use the invoices table

# %%
# %%sql SELECT CustomerId, Total
# FROM invoices
# WHERE InvoiceDate
# LIKE '2013-%'
# ORDER BY Total DESC LIMIT 3;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(6, 25.86), (39, 13.86), (18, 13.86)]

# %% [markdown]
# ## Problem 8

# %% [markdown]
# Querying the same table, can you determine the top 5 countries from which you are deriving most of your sales? You can infer this from the 'BillingCountry' column.
#
# Hint: Provide your answer in descending order

# %%
# %%sql SELECT BillingCountry, ROUND(SUM(Total)) AS Total
# FROM invoices
# GROUP BY BillingCountry
# ORDER BY
# ROUND(SUM(Total)) DESC
# LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('USA', 523.0),
#  ('Canada', 304.0),
#  ('France', 195.0),
#  ('Brazil', 190.0),
#  ('Germany', 156.0)]

# %% [markdown]
# ## Problem 9

# %% [markdown]
# One of your customers called customer service earlier today to enquire about a free gift that he/she never received. You wrote down his/her contact information, but spilled coffee all over the post-it note!
#
# The only legible words on your note are 'gmail.com' and a first name that seems to begin with 'He'. You also remember the customer has a thick European accent.
#
# Querying the Customers table, can you find out who this and his/her address to post that free gift?

# %%
# %%sql SELECT * FROM Customers
# WHERE Email LIKE '%@gmail.com'
# AND FirstName LIKE '%He%'
# Out:
#  * sqlite:///chinook.db
# Done.
# [(6, 'Helena', 'Holý', None, 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', '+420 2 4177 0449', None, 'hholy@gmail.com', 5),
#  (22, 'Heather', 'Leacock', None, '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', '+1 (407) 999-7788', None, 'hleacock@gmail.com', 4)]

# %% [markdown]
# ## Problem 10

# %% [markdown]
# You're about to go on an hour long road trip, and you want to select a song that lasts longer than one hour. Which tracks fulfil this condition?

# %%
# %%sql SELECT Name, (Milliseconds/3600002) AS Hour
# FROM tracks;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock (We Salute You)', 0),
#  ('Balls to the Wall', 0),
#  ('Fast As a Shark', 0),
#  ('Restless and Wild', 0),
#  ('Princess of the Dawn', 0),
#  ('Put The Finger On You', 0),
#  ("Let's Get It Up", 0),
#  ('Inject The Venom', 0),
#  ('Snowballed', 0),
#  ('Evil Walks', 0),
#  ('C.O.D.', 0),
#  ('Breaking The Rules', 0),
#  ('Night Of The Long Knives', 0),
#  ('Spellbound', 0),
#  ('Go Down', 0),
#  ('Dog Eat Dog', 0),
#  ('Let There Be Rock', 0),
#  ('Bad Boy Boogie', 0),
#  ('Problem Child', 0),
#  ('Overdose', 0),
#  ("Hell Ain't A Bad Place To Be", 0),
#  ('Whole Lotta Rosie', 0),
#  ('Walk On Water', 0),
#  ('Love In An Elevator', 0),
#  ('Rag Doll', 0),
#  ('What It Takes', 0),
#  ('Dude (Looks Like A Lady)', 0),
#  ("Janie's Got A Gun", 0),
#  ("Cryin'", 0),
#  ('Amazing', 0),
#  ('Blind Man', 0),
#  ('Deuces Are Wild', 0),
#  ('The Other Side', 0),
#  ('Crazy', 0),
#  ('Eat The Rich', 0),
#  ('Angel', 0),
#  ("Livin' On The Edge", 0),
#  ('All I Really Want', 0),
#  ('You Oughta Know', 0),
#  ('Perfect', 0),
#  ('Hand In My Pocket', 0),
#  ('Right Through You', 0),
#  ('Forgiven', 0),
#  ('You Learn', 0),
#  ('Head Over Feet', 0),
#  ('Mary Jane', 0),
#  ('Ironic', 0),
#  ('Not The Doctor', 0),
#  ('Wake Up', 0),
#  ('You Oughta Know (Alternate)', 0),
#  ('We Die Young', 0),
#  ('Man In The Box', 0),
#  ('Sea Of Sorrow', 0),
#  ('Bleed The Freak', 0),
#  ("I Can't Remember", 0),
#  ('Love, Hate, Love', 0),
#  ("It Ain't Like That", 0),
#  ('Sunshine', 0),
#  ('Put You Down', 0),
#  ('Confusion', 0),
#  ('I Know Somethin (Bout You)', 0),
#  ('Real Thing', 0),
#  ('Desafinado', 0),
#  ('Garota De Ipanema', 0),
#  ('Samba De Uma Nota Só (One Note Samba)', 0),
#  ('Por Causa De Você', 0),
#  ('Ligia', 0),
#  ('Fotografia', 0),
#  ('Dindi (Dindi)', 0),
#  ('Se Todos Fossem Iguais A Você (Instrumental)', 0),
#  ('Falando De Amor', 0),
#  ('Angela', 0),
#  ('Corcovado (Quiet Nights Of Quiet Stars)', 0),
#  ('Outra Vez', 0),
#  ('O Boto (Bôto)', 0),
#  ('Canta, Canta Mais', 0),
#  ('Enter Sandman', 0),
#  ('Master Of Puppets', 0),
#  ('Harvester Of Sorrow', 0),
#  ('The Unforgiven', 0),
#  ('Sad But True', 0),
#  ('Creeping Death', 0),
#  ('Wherever I May Roam', 0),
#  ('Welcome Home (Sanitarium)', 0),
#  ('Cochise', 0),
#  ('Show Me How to Live', 0),
#  ('Gasoline', 0),
#  ('What You Are', 0),
#  ('Like a Stone', 0),
#  ('Set It Off', 0),
#  ('Shadow on the Sun', 0),
#  ('I am the Highway', 0),
#  ('Exploder', 0),
#  ('Hypnotize', 0),
#  ("Bring'em Back Alive", 0),
#  ('Light My Way', 0),
#  ('Getaway Car', 0),
#  ('The Last Remaining Light', 0),
#  ('Your Time Has Come', 0),
#  ('Out Of Exile', 0),
#  ('Be Yourself', 0),
#  ("Doesn't Remind Me", 0),
#  ('Drown Me Slowly', 0),
#  ("Heaven's Dead", 0),
#  ('The Worm', 0),
#  ('Man Or Animal', 0),
#  ('Yesterday To Tomorrow', 0),
#  ('Dandelion', 0),
#  ('#1 Zero', 0),
#  ('The Curse', 0),
#  ('Money', 0),
#  ('Long Tall Sally', 0),
#  ('Bad Boy', 0),
#  ('Twist And Shout', 0),
#  ('Please Mr. Postman', 0),
#  ("C'Mon Everybody", 0),
#  ("Rock 'N' Roll Music", 0),
#  ('Slow Down', 0),
#  ('Roadrunner', 0),
#  ('Carol', 0),
#  ('Good Golly Miss Molly', 0),
#  ('20 Flight Rock', 0),
#  ('Quadrant', 0),
#  ("Snoopy's search-Red baron", 0),
#  ('Spanish moss-"A sound portrait"-Spanish moss', 0),
#  ('Moon germs', 0),
#  ('Stratus', 0),
#  ('The pleasant pheasant', 0),
#  ('Solo-Panhandler', 0),
#  ('Do what cha wanna', 0),
#  ('Intro/ Low Down', 0),
#  ('13 Years Of Grief', 0),
#  ('Stronger Than Death', 0),
#  ('All For You', 0),
#  ('Super Terrorizer', 0),
#  ('Phoney Smile Fake Hellos', 0),
#  ('Lost My Better Half', 0),
#  ('Bored To Tears', 0),
#  ('A.N.D.R.O.T.A.Z.', 0),
#  ('Born To Booze', 0),
#  ('World Of Trouble', 0),
#  ('No More Tears', 0),
#  ('The Begining... At Last', 0),
#  ('Heart Of Gold', 0),
#  ('Snowblind', 0),
#  ('Like A Bird', 0),
#  ('Blood In The Wall', 0),
#  ('The Beginning...At Last', 0),
#  ('Black Sabbath', 0),
#  ('The Wizard', 0),
#  ('Behind The Wall Of Sleep', 0),
#  ('N.I.B.', 0),
#  ('Evil Woman', 0),
#  ('Sleeping Village', 0),
#  ('Warning', 0),
#  ('Wheels Of Confusion / The Straightener', 0),
#  ("Tomorrow's Dream", 0),
#  ('Changes', 0),
#  ('FX', 0),
#  ('Supernaut', 0),
#  ('Snowblind', 0),
#  ('Cornucopia', 0),
#  ('Laguna Sunrise', 0),
#  ('St. Vitus Dance', 0),
#  ('Under The Sun/Every Day Comes and Goes', 0),
#  ('Smoked Pork', 0),
#  ("Body Count's In The House", 0),
#  ('Now Sports', 0),
#  ('Body Count', 0),
#  ('A Statistic', 0),
#  ('Bowels Of The Devil', 0),
#  ('The Real Problem', 0),
#  ('KKK Bitch', 0),
#  ('D Note', 0),
#  ('Voodoo', 0),
#  ('The Winner Loses', 0),
#  ('There Goes The Neighborhood', 0),
#  ('Oprah', 0),
#  ('Evil Dick', 0),
#  ('Body Count Anthem', 0),
#  ("Momma's Gotta Die Tonight", 0),
#  ('Freedom Of Speech', 0),
#  ('King In Crimson', 0),
#  ('Chemical Wedding', 0),
#  ('The Tower', 0),
#  ('Killing Floor', 0),
#  ('Book Of Thel', 0),
#  ('Gates Of Urizen', 0),
#  ('Jerusalem', 0),
#  ('Trupets Of Jericho', 0),
#  ('Machine Men', 0),
#  ('The Alchemist', 0),
#  ('Realword', 0),
#  ('First Time I Met The Blues', 0),
#  ('Let Me Love You Baby', 0),
#  ('Stone Crazy', 0),
#  ('Pretty Baby', 0),
#  ('When My Left Eye Jumps', 0),
#  ('Leave My Girl Alone', 0),
#  ('She Suits Me To A Tee', 0),
#  ('Keep It To Myself (Aka Keep It To Yourself)', 0),
#  ('My Time After Awhile', 0),
#  ('Too Many Ways (Alternate)', 0),
#  ("Talkin' 'Bout Women Obviously", 0),
#  ('Jorge Da Capadócia', 0),
#  ('Prenda Minha', 0),
#  ('Meditação', 0),
#  ('Terra', 0),
#  ('Eclipse Oculto', 0),
#  ('Texto "Verdade Tropical"', 0),
#  ('Bem Devagar', 0),
#  ('Drão', 0),
#  ('Saudosismo', 0),
#  ('Carolina', 0),
#  ('Sozinho', 0),
#  ('Esse Cara', 0),
#  ('Mel', 0),
#  ('Linha Do Equador', 0),
#  ('Odara', 0),
#  ('A Luz De Tieta', 0),
#  ('Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', 0),
#  ('Vida Boa', 0),
#  ('Sozinho (Hitmakers Classic Mix)', 0),
#  ('Sozinho (Hitmakers Classic Radio Edit)', 0),
#  ("Sozinho (Caêdrum 'n' Bass)", 0),
#  ('Carolina', 0),
#  ('Essa Moça Ta Diferente', 0),
#  ('Vai Passar', 0),
#  ('Samba De Orly', 0),
#  ('Bye, Bye Brasil', 0),
#  ('Atras Da Porta', 0),
#  ('Tatuagem', 0),
#  ('O Que Será (À Flor Da Terra)', 0),
#  ('Morena De Angola', 0),
#  ('Apesar De Você', 0),
#  ('A Banda', 0),
#  ('Minha Historia', 0),
#  ('Com Açúcar E Com Afeto', 0),
#  ('Brejo Da Cruz', 0),
#  ('Meu Caro Amigo', 0),
#  ('Geni E O Zepelim', 0),
#  ('Trocando Em Miúdos', 0),
#  ('Vai Trabalhar Vagabundo', 0),
#  ("Gota D'água", 0),
#  ('Construção / Deus Lhe Pague', 0),
#  ('Mateus Enter', 0),
#  ('O Cidadão Do Mundo', 0),
#  ('Etnia', 0),
#  ('Quilombo Groove [Instrumental]', 0),
#  ('Macô', 0),
#  ('Um Passeio No Mundo Livre', 0),
#  ('Samba Do Lado', 0),
#  ('Maracatu Atômico', 0),
#  ('O Encontro De Isaac Asimov Com Santos Dumont No Céu', 0),
#  ('Corpo De Lama', 0),
#  ('Sobremesa', 0),
#  ('Manguetown', 0),
#  ('Um Satélite Na Cabeça', 0),
#  ('Baião Ambiental [Instrumental]', 0),
#  ('Sangue De Bairro', 0),
#  ('Enquanto O Mundo Explode', 0),
#  ('Interlude Zumbi', 0),
#  ('Criança De Domingo', 0),
#  ('Amor De Muito', 0),
#  ('Samidarish [Instrumental]', 0),
#  ('Maracatu Atômico [Atomic Version]', 0),
#  ('Maracatu Atômico [Ragga Mix]', 0),
#  ('Maracatu Atômico [Trip Hop]', 0),
#  ('Banditismo Por Uma Questa', 0),
#  ('Banditismo Por Uma Questa', 0),
#  ('Rios Pontes & Overdrives', 0),
#  ('Cidade', 0),
#  ('Praiera', 0),
#  ('Samba Makossa', 0),
#  ('Da Lama Ao Caos', 0),
#  ('Maracatu De Tiro Certeiro', 0),
#  ('Salustiano Song', 0),
#  ('Antene Se', 0),
#  ('Risoflora', 0),
#  ('Lixo Do Mangue', 0),
#  ('Computadores Fazem Arte', 0),
#  ('Girassol', 0),
#  ('A Sombra Da Maldade', 0),
#  ('Johnny B. Goode', 0),
#  ('Soldado Da Paz', 0),
#  ('Firmamento', 0),
#  ('Extra', 0),
#  ('O Erê', 0),
#  ('Podes Crer', 0),
#  ('A Estrada', 0),
#  ('Berlim', 0),
#  ('Já Foi', 0),
#  ('Onde Você Mora?', 0),
#  ('Pensamento', 0),
#  ('Conciliação', 0),
#  ('Realidade Virtual', 0),
#  ('Mensagem', 0),
#  ('A Cor Do Sol', 0),
#  ('Onde Você Mora?', 0),
#  ('O Erê', 0),
#  ('A Sombra Da Maldade', 0),
#  ('A Estrada', 0),
#  ('Falar A Verdade', 0),
#  ('Firmamento', 0),
#  ('Pensamento', 0),
#  ('Realidade Virtual', 0),
#  ('Doutor', 0),
#  ('Na Frente Da TV', 0),
#  ('Downtown', 0),
#  ('Sábado A Noite', 0),
#  ('A Cor Do Sol', 0),
#  ('Eu Também Quero Beijar', 0),
#  ('Noite Do Prazer', 0),
#  ('À Francesa', 0),
#  ('Cada Um Cada Um (A Namoradeira)', 0),
#  ('Linha Do Equador', 0),
#  ('Amor Demais', 0),
#  ('Férias', 0),
#  ('Gostava Tanto De Você', 0),
#  ('Flor Do Futuro', 0),
#  ('Felicidade Urgente', 0),
#  ('Livre Pra Viver', 0),
#  ('Dig-Dig, Lambe-Lambe (Ao Vivo)', 0),
#  ('Pererê', 0),
#  ('TriboTchan', 0),
#  ('Tapa Aqui, Descobre Ali', 0),
#  ('Daniela', 0),
#  ('Bate Lata', 0),
#  ('Garotas do Brasil', 0),
#  ('Levada do Amor (Ailoviu)', 0),
#  ('Lavadeira', 0),
#  ('Reboladeira', 0),
#  ('É que Nessa Encarnação Eu Nasci Manga', 0),
#  ('Reggae Tchan', 0),
#  ('My Love', 0),
#  ('Latinha de Cerveja', 0),
#  ('You Shook Me', 0),
#  ("I Can't Quit You Baby", 0),
#  ('Communication Breakdown', 0),
#  ('Dazed and Confused', 0),
#  ('The Girl I Love She Got Long Black Wavy Hair', 0),
#  ('What is and Should Never Be', 0),
#  ('Communication Breakdown(2)', 0),
#  ('Travelling Riverside Blues', 0),
#  ('Whole Lotta Love', 0),
#  ("Somethin' Else", 0),
#  ('Communication Breakdown(3)', 0),
#  ("I Can't Quit You Baby(2)", 0),
#  ('You Shook Me(2)', 0),
#  ('How Many More Times', 0),
#  ('Debra Kadabra', 0),
#  ('Carolina Hard-Core Ecstasy', 0),
#  ('Sam With The Showing Scalp Flat Top', 0),
#  ("Poofter's Froth Wyoming Plans Ahead", 0),
#  ('200 Years Old', 0),
#  ('Cucamonga', 0),
#  ('Advance Romance', 0),
#  ('Man With The Woman Head', 0),
#  ('Muffin Man', 0),
#  ('Vai-Vai 2001', 0),
#  ('X-9 2001', 0),
#  ('Gavioes 2001', 0),
#  ('Nene 2001', 0),
#  ('Rosas De Ouro 2001', 0),
#  ('Mocidade Alegre 2001', 0),
#  ('Camisa Verde 2001', 0),
#  ('Leandro De Itaquera 2001', 0),
#  ('Tucuruvi 2001', 0),
#  ('Aguia De Ouro 2001', 0),
#  ('Ipiranga 2001', 0),
#  ('Morro Da Casa Verde 2001', 0),
#  ('Perola Negra 2001', 0),
#  ('Sao Lucas 2001', 0),
#  ('Guanabara', 0),
#  ('Mas Que Nada', 0),
#  ('Vôo Sobre o Horizonte', 0),
#  ('A Paz', 0),
#  ('Wave (Vou te Contar)', 0),
#  ('Água de Beber', 0),
#  ('Samba da Bençaco', 0),
#  ('Pode Parar', 0),
#  ('Menino do Rio', 0),
#  ('Ando Meio Desligado', 0),
#  ('Mistério da Raça', 0),
#  ('All Star', 0),
#  ('Menina Bonita', 0),
#  ('Pescador de Ilusões', 0),
#  ('À Vontade (Live Mix)', 0),
#  ('Maria Fumaça', 0),
#  ('Sambassim (dj patife remix)', 0),
#  ('Garota De Ipanema', 0),
#  ('Tim Tim Por Tim Tim', 0),
#  ('Tarde Em Itapoã', 0),
#  ('Tanto Tempo', 0),
#  ('Eu Vim Da Bahia - Live', 0),
#  ('Alô Alô Marciano', 0),
#  ('Linha Do Horizonte', 0),
#  ('Only A Dream In Rio', 0),
#  ('Abrir A Porta', 0),
#  ('Alice', 0),
#  ('Momentos Que Marcam', 0),
#  ('Um Jantar Pra Dois', 0),
#  ('Bumbo Da Mangueira', 0),
#  ('Mr Funk Samba', 0),
#  ('Santo Antonio', 0),
#  ('Por Você', 0),
#  ('Só Tinha De Ser Com Você', 0),
#  ('Free Speech For The Dumb', 0),
#  ("It's Electric", 0),
#  ('Sabbra Cadabra', 0),
#  ('Turn The Page', 0),
#  ('Die Die My Darling', 0),
#  ('Loverman', 0),
#  ('Mercyful Fate', 0),
#  ('Astronomy', 0),
#  ('Whiskey In The Jar', 0),
#  ("Tuesday's Gone", 0),
#  ('The More I See', 0),
#  ('A Kind Of Magic', 0),
#  ('Under Pressure', 0),
#  ('Radio GA GA', 0),
#  ('I Want It All', 0),
#  ('I Want To Break Free', 0),
#  ('Innuendo', 0),
#  ("It's A Hard Life", 0),
#  ('Breakthru', 0),
#  ('Who Wants To Live Forever', 0),
#  ('Headlong', 0),
#  ('The Miracle', 0),
#  ("I'm Going Slightly Mad", 0),
#  ('The Invisible Man', 0),
#  ('Hammer To Fall', 0),
#  ('Friends Will Be Friends', 0),
#  ('The Show Must Go On', 0),
#  ('One Vision', 0),
#  ('Detroit Rock City', 0),
#  ('Black Diamond', 0),
#  ('Hard Luck Woman', 0),
#  ('Sure Know Something', 0),
#  ('Love Gun', 0),
#  ('Deuce', 0),
#  ("Goin' Blind", 0),
#  ('Shock Me', 0),
#  ('Do You Love Me', 0),
#  ('She', 0),
#  ('I Was Made For Loving You', 0),
#  ('Shout It Out Loud', 0),
#  ('God Of Thunder', 0),
#  ('Calling Dr. Love', 0),
#  ('Beth', 0),
#  ('Strutter', 0),
#  ('Rock And Roll All Nite', 0),
#  ('Cold Gin', 0),
#  ('Plaster Caster', 0),
#  ("God Gave Rock 'n' Roll To You", 0),
#  ('Heart of the Night', 0),
#  ('De La Luz', 0),
#  ('Westwood Moon', 0),
#  ('Midnight', 0),
#  ('Playtime', 0),
#  ('Surrender', 0),
#  ("Valentino's", 0),
#  ('Believe', 0),
#  ('As We Sleep', 0),
#  ('When Evening Falls', 0),
#  ('J Squared', 0),
#  ('Best Thing', 0),
#  ('Maria', 0),
#  ('Poprocks And Coke', 0),
#  ('Longview', 0),
#  ('Welcome To Paradise', 0),
#  ('Basket Case', 0),
#  ('When I Come Around', 0),
#  ('She', 0),
#  ('J.A.R. (Jason Andrew Relva)', 0),
#  ('Geek Stink Breath', 0),
#  ('Brain Stew', 0),
#  ('Jaded', 0),
#  ('Walking Contradiction', 0),
#  ('Stuck With Me', 0),
#  ("Hitchin' A Ride", 0),
#  ('Good Riddance (Time Of Your Life)', 0),
#  ('Redundant', 0),
#  ('Nice Guys Finish Last', 0),
#  ('Minority', 0),
#  ('Warning', 0),
#  ('Waiting', 0),
#  ("Macy's Day Parade", 0),
#  ('Into The Light', 0),
#  ('River Song', 0),
#  ('She Give Me ...', 0),
#  ("Don't You Cry", 0),
#  ('Love Is Blind', 0),
#  ('Slave', 0),
#  ('Cry For Love', 0),
#  ('Living On Love', 0),
#  ('Midnight Blue', 0),
#  ('Too Many Tears', 0),
#  ("Don't Lie To Me", 0),
#  ('Wherever You May Go', 0),
#  ('Grito De Alerta', 0),
#  ('Não Dá Mais Pra Segurar (Explode Coração)', 0),
#  ('Começaria Tudo Outra Vez', 0),
#  ('O Que É O Que É ?', 0),
#  ('Sangrando', 0),
#  ('Diga Lá, Coração', 0),
#  ('Lindo Lago Do Amor', 0),
#  ('Eu Apenas Queria Que Voçê Soubesse', 0),
#  ('Com A Perna No Mundo', 0),
#  ('E Vamos À Luta', 0),
#  ('Um Homem Também Chora (Guerreiro Menino)', 0),
#  ('Comportamento Geral', 0),
#  ('Ponto De Interrogação', 0),
#  ('Espere Por Mim, Morena', 0),
#  ('Meia-Lua Inteira', 0),
#  ('Voce e Linda', 0),
#  ('Um Indio', 0),
#  ('Podres Poderes', 0),
#  ('Voce Nao Entende Nada - Cotidiano', 0),
#  ('O Estrangeiro', 0),
#  ('Menino Do Rio', 0),
#  ('Qualquer Coisa', 0),
#  ('Sampa', 0),
#  ('Queixa', 0),
#  ('O Leaozinho', 0),
#  ('Fora Da Ordem', 0),
#  ('Terra', 0),
#  ('Alegria, Alegria', 0),
#  ('Balada Do Louco', 0),
#  ('Ando Meio Desligado', 0),
#  ('Top Top', 0),
#  ('Baby', 0),
#  ('A E O Z', 0),
#  ('Panis Et Circenses', 0),
#  ('Chão De Estrelas', 0),
#  ('Vida De Cachorro', 0),
#  ('Bat Macumba', 0),
#  ('Desculpe Babe', 0),
#  ('Rita Lee', 0),
#  ('Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll', 0),
#  ('Banho De Lua', 0),
#  ('Meu Refrigerador Não Funciona', 0),
#  ('Burn', 0),
#  ('Stormbringer', 0),
#  ('Gypsy', 0),
#  ('Lady Double Dealer', 0),
#  ('Mistreated', 0),
#  ('Smoke On The Water', 0),
#  ('You Fool No One', 0),
#  ('Custard Pie', 0),
#  ('The Rover', 0),
#  ('In My Time Of Dying', 0),
#  ('Houses Of The Holy', 0),
#  ('Trampled Under Foot', 0),
#  ('Kashmir', 0),
#  ('Imperatriz', 0),
#  ('Beija-Flor', 0),
#  ('Viradouro', 0),
#  ('Mocidade', 0),
#  ('Unidos Da Tijuca', 0),
#  ('Salgueiro', 0),
#  ('Mangueira', 0),
#  ('União Da Ilha', 0),
#  ('Grande Rio', 0),
#  ('Portela', 0),
#  ('Caprichosos', 0),
#  ('Tradição', 0),
#  ('Império Serrano', 0),
#  ('Tuiuti', 0),
#  ('(Da Le) Yaleo', 0),
#  ('Love Of My Life', 0),
#  ('Put Your Lights On', 0),
#  ('Africa Bamba', 0),
#  ('Smooth', 0),
#  ('Do You Like The Way', 0),
#  ('Maria Maria', 0),
#  ('Migra', 0),
#  ('Corazon Espinado', 0),
#  ('Wishing It Was', 0),
#  ('El Farol', 0),
#  ('Primavera', 0),
#  ('The Calling', 0),
#  ('Solução', 0),
#  ('Manuel', 0),
#  ('Entre E Ouça', 0),
#  ('Um Contrato Com Deus', 0),
#  ('Um Jantar Pra Dois', 0),
#  ('Vamos Dançar', 0),
#  ('Um Love', 0),
#  ('Seis Da Tarde', 0),
#  ('Baixo Rio', 0),
#  ('Sombras Do Meu Destino', 0),
#  ('Do You Have Other Loves?', 0),
#  ('Agora Que O Dia Acordou', 0),
#  ('Já!!!', 0),
#  ('A Rua', 0),
#  ("Now's The Time", 0),
#  ('Jeru', 0),
#  ('Compulsion', 0),
#  ('Tempus Fugit', 0),
#  ("Walkin'", 0),
#  ("'Round Midnight", 0),
#  ('Bye Bye Blackbird', 0),
#  ('New Rhumba', 0),
#  ('Generique', 0),
#  ('Summertime', 0),
#  ('So What', 0),
#  ('The Pan Piper', 0),
#  ('Someday My Prince Will Come', 0),
#  ('My Funny Valentine (Live)', 0),
#  ('E.S.P.', 0),
#  ('Nefertiti', 0),
#  ('Petits Machins (Little Stuff)', 0),
#  ('Miles Runs The Voodoo Down', 0),
#  ('Little Church (Live)', 0),
#  ('Black Satin', 0),
#  ('Jean Pierre (Live)', 0),
#  ('Time After Time', 0),
#  ('Portia', 0),
#  ("Space Truckin'", 0),
#  ('Going Down / Highway Star', 0),
#  ('Mistreated (Alternate Version)', 0),
#  ('You Fool No One (Alternate Version)', 0),
#  ('Jeepers Creepers', 0),
#  ('Blue Rythm Fantasy', 0),
#  ('Drum Boogie', 0),
#  ('Let Me Off Uptown', 0),
#  ('Leave Us Leap', 0),
#  ('Opus No.1', 0),
#  ('Boogie Blues', 0),
#  ('How High The Moon', 0),
#  ('Disc Jockey Jump', 0),
#  ("Up An' Atom", 0),
#  ('Bop Boogie', 0),
#  ('Lemon Drop', 0),
#  ('Coronation Drop', 0),
#  ('Overtime', 0),
#  ('Imagination', 0),
#  ("Don't Take Your Love From Me", 0),
#  ('Midget', 0),
#  ("I'm Coming Virginia", 0),
#  ("Payin' Them Dues Blues", 0),
#  ('Jungle Drums', 0),
#  ('Showcase', 0),
#  ('Swedish Schnapps', 0),
#  ('Samba Da Bênção', 0),
#  ('Pot-Pourri N.º 4', 0),
#  ('Onde Anda Você', 0),
#  ('Samba Da Volta', 0),
#  ('Canto De Ossanha', 0),
#  ('Pot-Pourri N.º 5', 0),
#  ('Formosa', 0),
#  ('Como É Duro Trabalhar', 0),
#  ('Minha Namorada', 0),
#  ('Por Que Será', 0),
#  ('Berimbau', 0),
#  ('Deixa', 0),
#  ('Pot-Pourri N.º 2', 0),
#  ('Samba Em Prelúdio', 0),
#  ('Carta Ao Tom 74', 0),
#  ('Linha de Passe (João Bosco)', 0),
#  ('Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)', 0),
#  ('Chão de Giz (Elba Ramalho)', 0),
#  ('Marina (Dorival Caymmi)', 0),
#  ('Aquarela (Toquinho)', 0),
#  ('Coração do Agreste (Fafá de Belém)', 0),
#  ('Dona (Roupa Nova)', 0),
#  ('Começaria Tudo Outra Vez (Maria Creuza)', 0),
#  ('Caçador de Mim (Sá & Guarabyra)', 0),
#  ('Romaria (Renato Teixeira)', 0),
#  ('As Rosas Não Falam (Beth Carvalho)', 0),
#  ('Wave (Os Cariocas)', 0),
#  ('Garota de Ipanema (Dick Farney)', 0),
#  ('Preciso Apender a Viver Só (Maysa)', 0),
#  ('Susie Q', 0),
#  ('I Put A Spell On You', 0),
#  ('Proud Mary', 0),
#  ('Bad Moon Rising', 0),
#  ('Lodi', 0),
#  ('Green River', 0),
#  ('Commotion', 0),
#  ('Down On The Corner', 0),
#  ('Fortunate Son', 0),
#  ("Travelin' Band", 0),
#  ("Who'll Stop The Rain", 0),
#  ('Up Around The Bend', 0),
#  ('Run Through The Jungle', 0),
#  ("Lookin' Out My Back Door", 0),
#  ('Long As I Can See The Light', 0),
#  ('I Heard It Through The Grapevine', 0),
#  ('Have You Ever Seen The Rain?', 0),
#  ('Hey Tonight', 0),
#  ('Sweet Hitch-Hiker', 0),
#  ('Someday Never Comes', 0),
#  ('Walking On The Water', 0),
#  ('Suzie-Q, Pt. 2', 0),
#  ('Born On The Bayou', 0),
#  ('Good Golly Miss Molly', 0),
#  ('Tombstone Shadow', 0),
#  ('Wrote A Song For Everyone', 0),
#  ('Night Time Is The Right Time', 0),
#  ('Cotton Fields', 0),
#  ('It Came Out Of The Sky', 0),
#  ("Don't Look Now", 0),
#  ('The Midnight Special', 0),
#  ('Before You Accuse Me', 0),
#  ('My Baby Left Me', 0),
#  ('Pagan Baby', 0),
#  ('(Wish I Could) Hideaway', 0),
#  ("It's Just A Thought", 0),
#  ('Molina', 0),
#  ('Born To Move', 0),
#  ("Lookin' For A Reason", 0),
#  ('Hello Mary Lou', 0),
#  ('Gatas Extraordinárias', 0),
#  ('Brasil', 0),
#  ('Eu Sou Neguinha (Ao Vivo)', 0),
#  ('Geração Coca-Cola (Ao Vivo)', 0),
#  ('Lanterna Dos Afogados', 0),
#  ('Coroné Antonio Bento', 0),
#  ('Você Passa, Eu Acho Graça (Ao Vivo)', 0),
#  ('Meu Mundo Fica Completo (Com Você)', 0),
#  ('1° De Julho', 0),
#  ('Música Urbana 2', 0),
#  ('Vida Bandida (Ao Vivo)', 0),
#  ('Palavras Ao Vento', 0),
#  ('Não Sei O Que Eu Quero Da Vida', 0),
#  ('Woman Is The Nigger Of The World (Ao Vivo)', 0),
#  ('Juventude Transviada (Ao Vivo)', 0),
#  ('Malandragem', 0),
#  ('O Segundo Sol', 0),
#  ('Smells Like Teen Spirit (Ao Vivo)', 0),
#  ('E.C.T.', 0),
#  ('Todo Amor Que Houver Nesta Vida', 0),
#  ('Metrô. Linha 743', 0),
#  ('Nós (Ao Vivo)', 0),
#  ('Na Cadência Do Samba', 0),
#  ('Admirável Gado Novo', 0),
#  ('Eleanor Rigby', 0),
#  ('Socorro', 0),
#  ('Blues Da Piedade', 0),
#  ('Rubens', 0),
#  ('Não Deixe O Samba Morrer - Cassia Eller e Alcione', 0),
#  ('Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', 0),
#  ("Comin' Home", 0),
#  ('Lady Luck', 0),
#  ("Gettin' Tighter", 0),
#  ('Dealer', 0),
#  ('I Need Love', 0),
#  ('Drifter', 0),
#  ('Love Child', 0),
#  ("This Time Around / Owed to 'G' [Instrumental]", 0),
#  ('You Keep On Moving', 0),
#  ('Speed King', 0),
#  ('Bloodsucker', 0),
#  ('Child In Time', 0),
#  ('Flight Of The Rat', 0),
#  ('Into The Fire', 0),
#  ('Living Wreck', 0),
#  ("Hard Lovin' Man", 0),
#  ('Fireball', 0),
#  ('No No No', 0),
#  ('Strange Kind Of Woman', 0),
#  ("Anyone's Daughter", 0),
#  ('The Mule', 0),
#  ('Fools', 0),
#  ('No One Came', 0),
#  ('Knocking At Your Back Door', 0),
#  ('Bad Attitude', 0),
#  ('Child In Time (Son Of Aleric - Instrumental)', 0),
#  ("Nobody's Home", 0),
#  ('Black Night', 0),
#  ('Perfect Strangers', 0),
#  ('The Unwritten Law', 0),
#  ('Call Of The Wild', 0),
#  ('Hush', 0),
#  ('Smoke On The Water', 0),
#  ('Space Trucking', 0),
#  ('Highway Star', 0),
#  ("Maybe I'm A Leo", 0),
#  ('Pictures Of Home', 0),
#  ('Never Before', 0),
#  ('Smoke On The Water', 0),
#  ('Lazy', 0),
#  ("Space Truckin'", 0),
#  ('Vavoom : Ted The Mechanic', 0),
#  ('Loosen My Strings', 0),
#  ('Soon Forgotten', 0),
#  ('Sometimes I Feel Like Screaming', 0),
#  ("Cascades : I'm Not Your Lover", 0),
#  ('The Aviator', 0),
#  ("Rosa's Cantina", 0),
#  ('A Castle Full Of Rascals', 0),
#  ('A Touch Away', 0),
#  ('Hey Cisco', 0),
#  ('Somebody Stole My Guitar', 0),
#  ('The Purpendicular Waltz', 0),
#  ('King Of Dreams', 0),
#  ('The Cut Runs Deep', 0),
#  ('Fire In The Basement', 0),
#  ('Truth Hurts', 0),
#  ('Breakfast In Bed', 0),
#  ('Love Conquers All', 0),
#  ('Fortuneteller', 0),
#  ('Too Much Is Not Enough', 0),
#  ('Wicked Ways', 0),
#  ('Stormbringer', 0),
#  ("Love Don't Mean a Thing", 0),
#  ('Holy Man', 0),
#  ('Hold On', 0),
#  ('Lady Double Dealer', 0),
#  ("You Can't Do it Right (With the One You Love)", 0),
#  ('High Ball Shooter', 0),
#  ('The Gypsy', 0),
#  ('Soldier Of Fortune', 0),
#  ('The Battle Rages On', 0),
#  ('Lick It Up', 0),
#  ('Anya', 0),
#  ('Talk About Love', 0),
#  ('Time To Kill', 0),
#  ('Ramshackle Man', 0),
#  ('A Twist In The Tail', 0),
#  ('Nasty Piece Of Work', 0),
#  ('Solitaire', 0),
#  ("One Man's Meat", 0),
#  ('Pour Some Sugar On Me', 0),
#  ('Photograph', 0),
#  ('Love Bites', 0),
#  ("Let's Get Rocked", 0),
#  ('Two Steps Behind [Acoustic Version]', 0),
#  ('Animal', 0),
#  ('Heaven Is', 0),
#  ('Rocket', 0),
#  ('When Love & Hate Collide', 0),
#  ('Action', 0),
#  ('Make Love Like A Man', 0),
#  ('Armageddon It', 0),
#  ('Have You Ever Needed Someone So Bad', 0),
#  ('Rock Of Ages', 0),
#  ('Hysteria', 0),
#  ("Bringin' On The Heartbreak", 0),
#  ('Roll Call', 0),
#  ('Otay', 0),
#  ('Groovus Interruptus', 0),
#  ('Paris On Mine', 0),
#  ('In Time', 0),
#  ('Plan B', 0),
#  ('Outbreak', 0),
#  ('Baltimore, DC', 0),
#  ('Talkin Loud and Saying Nothin', 0),
#  ('Pétala', 0),
#  ('Meu Bem-Querer', 0),
#  ('Cigano', 0),
#  ('Boa Noite', 0),
#  ('Fato Consumado', 0),
#  ('Faltando Um Pedaço', 0),
#  ('Álibi', 0),
#  ('Esquinas', 0),
#  ('Se...', 0),
#  ('Eu Te Devoro', 0),
#  ('Lilás', 0),
#  ('Acelerou', 0),
#  ('Um Amor Puro', 0),
#  ('Samurai', 0),
#  ('Nem Um Dia', 0),
#  ('Oceano', 0),
#  ('Açai', 0),
#  ('Serrado', 0),
#  ('Flor De Lis', 0),
#  ('Amar É Tudo', 0),
#  ('Azul', 0),
#  ('Seduzir', 0),
#  ('A Carta', 0),
#  ('Sina', 0),
#  ('Acelerou', 0),
#  ('Um Amor Puro', 0),
#  ('O Bêbado e a Equilibrista', 0),
#  ('O Mestre-Sala dos Mares', 0),
#  ('Atrás da Porta', 0),
#  ('Dois Pra Lá, Dois Pra Cá', 0),
#  ('Casa no Campo', 0),
#  ('Romaria', 0),
#  ('Alô, Alô, Marciano', 0),
#  ('Me Deixas Louca', 0),
#  ('Fascinação', 0),
#  ('Saudosa Maloca', 0),
#  ('As Aparências Enganam', 0),
#  ('Madalena', 0),
#  ('Maria Rosa', 0),
#  ('Aprendendo A Jogar', 0),
#  ('Layla', 0),
#  ('Badge', 0),
#  ('I Feel Free', 0),
#  ('Sunshine Of Your Love', 0),
#  ('Crossroads', 0),
#  ('Strange Brew', 0),
#  ('White Room', 0),
#  ('Bell Bottom Blues', 0),
#  ('Cocaine', 0),
#  ('I Shot The Sheriff', 0),
#  ('After Midnight', 0),
#  ('Swing Low Sweet Chariot', 0),
#  ('Lay Down Sally', 0),
#  ('Knockin On Heavens Door', 0),
#  ('Wonderful Tonight', 0),
#  ('Let It Grow', 0),
#  ('Promises', 0),
#  ("I Can't Stand It", 0),
#  ('Signe', 0),
#  ('Before You Accuse Me', 0),
#  ('Hey Hey', 0),
#  ('Tears In Heaven', 0),
#  ('Lonely Stranger', 0),
#  ("Nobody Knows You When You're Down & Out", 0),
#  ('Layla', 0),
#  ('Running On Faith', 0),
#  ("Walkin' Blues", 0),
#  ('Alberta', 0),
#  ('San Francisco Bay Blues', 0),
#  ('Malted Milk', 0),
#  ('Old Love', 0),
#  ("Rollin' And Tumblin'", 0),
#  ('Collision', 0),
#  ('Stripsearch', 0),
#  ('Last Cup Of Sorrow', 0),
#  ('Naked In Front Of The Computer', 0),
#  ('Helpless', 0),
#  ('Mouth To Mouth', 0),
#  ('Ashes To Ashes', 0),
#  ('She Loves Me Not', 0),
#  ('Got That Feeling', 0),
#  ('Paths Of Glory', 0),
#  ('Home Sick Home', 0),
#  ('Pristina', 0),
#  ('Land Of Sunshine', 0),
#  ('Caffeine', 0),
#  ('Midlife Crisis', 0),
#  ('RV', 0),
#  ('Smaller And Smaller', 0),
#  ("Everything's Ruined", 0),
#  ('Malpractice', 0),
#  ('Kindergarten', 0),
#  ('Be Aggressive', 0),
#  ('A Small Victory', 0),
#  ('Crack Hitler', 0),
#  ('Jizzlobber', 0),
#  ('Midnight Cowboy', 0),
#  ('Easy', 0),
#  ('Get Out', 0),
#  ('Ricochet', 0),
#  ('Evidence', 0),
#  ('The Gentle Art Of Making Enemies', 0),
#  ('Star A.D.', 0),
#  ('Cuckoo For Caca', 0),
#  ('Caralho Voador', 0),
#  ('Ugly In The Morning', 0),
#  ('Digging The Grave', 0),
#  ('Take This Bottle', 0),
#  ('King For A Day', 0),
#  ('What A Day', 0),
#  ('The Last To Know', 0),
#  ('Just A Man', 0),
#  ('Absolute Zero', 0),
#  ('From Out Of Nowhere', 0),
#  ('Epic', 0),
#  ('Falling To Pieces', 0),
#  ("Surprise! You're Dead!", 0),
#  ('Zombie Eaters', 0),
#  ('The Real Thing', 0),
#  ('Underwater Love', 0),
#  ('The Morning After', 0),
#  ('Woodpecker From Mars', 0),
#  ('War Pigs', 0),
#  ('Edge Of The World', 0),
#  ('Deixa Entrar', 0),
#  ('Falamansa Song', 0),
#  ('Xote Dos Milagres', 0),
#  ('Rindo À Toa', 0),
#  ('Confidência', 0),
#  ('Forró De Tóquio', 0),
#  ('Zeca Violeiro', 0),
#  ('Avisa', 0),
#  ('Principiando/Decolagem', 0),
#  ('Asas', 0),
#  ('Medo De Escuro', 0),
#  ('Oração', 0),
#  ('Minha Gata', 0),
#  ('Desaforo', 0),
#  ('In Your Honor', 0),
#  ('No Way Back', 0),
#  ('Best Of You', 0),
#  ('DOA', 0),
#  ('Hell', 0),
#  ('The Last Song', 0),
#  ('Free Me', 0),
#  ('Resolve', 0),
#  ('The Deepest Blues Are Black', 0),
#  ('End Over End', 0),
#  ('Still', 0),
#  ('What If I Do?', 0),
#  ...]

# %%
# %%sql SELECT Name, TrackId, ROUND((Milliseconds*0.001)/60, 2) AS Duration
# FROM tracks
# WHERE Duration > 60
# ORDER BY Duration DESC;

# %% [markdown]
# ## Problem 11

# %% [markdown]
# What is the average duration for the all songs in your database? Give your answer in minutes rounded to two decimal places.

# %%
# %%sql SELECT ROUND(AVG((Milliseconds*0.001)/60), 2) AS Duration
# FROM tracks;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(6.56,)]

# %% [markdown]
# ## Problem 12

# %% [markdown]
# Which artist has produced the most albums?
#
# Hint: This can be acomplished with either a SubQuery or with a Join!

# %%
# %%sql SELECT Name
# FROM artists
# WHERE ArtistId =
# (SELECT ArtistId
#  FROM albums
#  GROUP BY ArtistId
#  ORDER BY COUNT(*)
#  DESC LIMIT 1);
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Iron Maiden',)]

# %% [markdown]
# ## Problem 13

# %% [markdown]
# The new CEO of our company has an obsession with streamlining data storage in the company. He wants to find tracks with the lowest Revenue per byte ratio in an attempt to improve our cost efficiency. Find the 10 worst performing songs in terms of Revenue / Byte. For easier interpretation please include a column 'Mb' that displays the number of bytes in megabytes as the CEO is only familiar with this unit.
#
# Hint: Use invoice_items and tracks tables

# %%
# %%sql SELECT t.Name, t.trackid, sum(Quantity)*i.unitprice AS Revenue,
# Bytes/1000000 AS Mb, (sum(Quantity)*i.unitprice)/Bytes AS Dollarspb
# FROM tracks t, invoice_items i
# WHERE t.TrackId = i.TrackId
# GROUP BY t.TrackId
# ORDER BY Dollarspb
# LIMIT 5;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Through a Looking Glass', 3224, 1.99, 1059, 1.878162663119135e-09),
#  ('Occupation / Precipice', 2820, 1.99, 1054, 1.887286425492465e-09),
#  ('Dave', 2910, 1.99, 574, 3.464932098674601e-09),
#  ('The Magnificent Warriors', 3235, 1.99, 570, 3.4902959039893752e-09),
#  ('The Lost Warrior', 3231, 1.99, 558, 3.5607425733601093e-09)]
